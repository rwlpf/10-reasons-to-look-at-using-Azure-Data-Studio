-- %% [markdown]
-- # <mark>What is the goal of the session?</mark></br>
-- ## What is he trying to do?</br>
-- ## One aim</br>
--
--
-- ![alt text](./Images_Notebook-01/target.jpg)</br>
--
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- <h1>Look at Azure Data Studio</h1>
--
-- ![alt text](./Images_Notebook-01/binoculars.jpg)</br>
-- Photo by mostafa meraji on Unsplash

-- %% [markdown]
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
--
--
-- # <mark> How much does Azure Data Studio cost?</mark>
--
-- ![alt text](./Images_Notebook-01/emptyhand.jpg)
-- </br>
-- Photo by Jeremy Yap on Unsplash
--
-- <h1> Zero</br>
-- Zip</br>
-- Zilch</br>
-- Nada</br>
-- Nothing</br>
-- Zero pounds and Zero Pence</br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>

-- %% [markdown]
-- # <mark> It's only for Windows !!!!! ?????</mark>
--
-- ![alt text](./Images_Notebook-01/WindowsButton.jpg)</br>
-- Photo by Tadas Sar on Unsplash
--
-- <br/>
-- <br/>
-- <br/>
-- <br/>
-- <br/>
-- <br/>
-- <br/>
--
-- ![alt text](https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fmedia.giphy.com%2Fmedia%2F3o7btT1T9qpQZWhNlK%2Fgiphy.gif&f=1&nofb=1)
--
-- <br/>
-- <br/>
-- <br/>
-- <br/>
-- <br/>
-- <br/>
-- <br/>
--
-- ![alt text](./Images_Notebook-01/No.jpg)</br>
-- Photo by Gemma Evans on Unsplash
--
-- <br/>
-- <br/>
-- <br/>
-- <br/>
-- <br/>
-- <br/>
-- <br/>
--
-- <h1> You can install on............... </h1>
--
-- ![alt text](./Images_Notebook-01/Windows.png)</br>
--
--
-- https://docs.microsoft.com/en-us/sql/azure-data-studio/download-azure-data-studio?view=sql-server-ver15#windows
--
-- # * Windows 10 (64-bit)
-- # * Windows 8.1 (64-bit)
-- # *  Windows 8 (64-bit)
-- # * Windows 7 (SP1) (64-bit) - Requires KB2533623
-- # * Windows Server 2019
-- # * Windows Server 2016
-- # * Windows Server 2012 R2 (64-bit)
-- # * Windows Server 2012 (64-bit)
-- # * Windows Server 2008 R2 (64-bit)
--
-- <br/>
-- <br/>
-- <br/>
-- <br/>
-- <br/>
-- <br/>
-- <br/>
--
-- ![alt text](./Images_Notebook-01/mac.png)</br>
--
-- https://docs.microsoft.com/en-us/sql/azure-data-studio/download-azure-data-studio?view=sql-server-ver15#macos
--
-- # * macOS 10.15 Catalina
-- # * macOS 10.14 Mojave
-- # * macOS 10.13 High Sierra
-- # * macOS 10.12 Sierra
--
-- <br/>
-- <br/>
-- <br/>
-- <br/>
-- <br/>
-- <br/>
-- <br/>
--
-- ![alt text](./Images_Notebook-01/220px-Tux.png)</br>
--
-- https://docs.microsoft.com/en-us/sql/azure-data-studio/download-azure-data-studio?view=sql-server-ver15#linux
--
-- # * Red Hat Enterprise Linux 7.4
-- # * Red Hat Enterprise Linux 7.3
-- # * SUSE Linux Enterprise Server v12 SP2
-- # * Ubuntu 16.04

-- %% [markdown]
-- ![alt text](./Images_Notebook-01/Windows.png)</br>
--
-- # AND
--
-- ![alt text](./Images_Notebook-01/mac.png)</br>
--
-- # AND
--
-- ![alt text](./Images_Notebook-01/220px-Tux.png)
--
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- ![alt text](https://media.giphy.com/media/n8SkNR77udWlG/giphy.gif)

-- %% [markdown]
-- # Who is he?
--
-- ## Robert French</BR>
-- ## Consultant with Eyecademy</br>
-- ## In Sunny Glasgow
--
-- ## Email - rwlp.french@gmail.com
--
-- ## Twitter - @SqlBobScot
--
-- ## Linked In - https://www.linkedin.com/in/rwlpfrench/
--
-- ## Blog - www.sqlbob.co.uk
