-- %% [markdown]
-- # Lets be clear
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- ![alt text](./Images_Notebook-02/love.jpg)
-- ###### Photo by Shaira Dela Peña on Unsplash
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- ![alt text](./Images_Notebook-02/SqlServerManagmentStudio.jpg)</br>
-- ###### Screenshot from SSMS
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- # It can be disappointing though.
--
--
-- ![alt text](./Images_Notebook-02/Disappointed.jpg)</br>
-- ###### Photo by Matthew Henry on Unsplash
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- # How many coloured themes can you get in SSMS?
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- ## Light
--
-- ![alt text](./Images_Notebook-02/light-bulb-1173249_640.jpg)</br>
--
-- ###### Image by Colin Behrens from Pixabay
--
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- ## Or dark
--
-- ![alt text](./Images_Notebook-02/dark_city.jpg)</br>
--
-- ###### Photo by Lance Anderson on Unsplash
--
-- # How many do you get in Azure Data Studio?
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- # Lets Look
--
-- ![alt text](./Images_Notebook-02/Look.jpg)</br>
-- ###### Photo by mari lezhava on Unsplash
--
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- ## Click on gear icon to "Manage"
--
-- ![alt text](./Images_Notebook-02/Select_Colour.jpg)</br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- ![alt text](./Images_Notebook-02/Red.jpg)</br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- ![alt text](./Images_Notebook-02/Solarized_Dark.jpg)</br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- ![alt text](./Images_Notebook-02/Stop.jpg)</br>
--
-- Photo by Nadine Shaabana on Unsplash
