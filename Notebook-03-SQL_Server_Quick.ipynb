-- %% [markdown]
-- # Have you installed SQL Server?
--
-- ![alt text](./Images_Notebook-03/SQL-Server-2019.jpg)
--
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- Did it take a long time, with lots of questions?
--
-- ![alt text](./Images_Notebook-03/long-Road-illiya-vjestica-zNTttcbHyX8-unsplash.jpg)
-- ###### Photo by Illiya Vjestica on Unsplash
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>

-- %% [markdown]
-- # What if there was an easier way?
--
-- </br>
--
-- ![alt text](./Images_Notebook-03/easier-drew-coffman-DzIt-fTYv4E-unsplash.jpg)
-- ###### Photo by Drew Coffman on Unsplash
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- # There are some tools required
-- ![alt text](./Images_Notebook-03/Toolobx-tekton-EcE9dFfXwwE-unsplash.jpg)
-- ###### Photo by Drew Coffman on Unsplash

-- %% [markdown]
-- # Azure Data Studio
--
-- ![alt text](./Images_Notebook-03/AzureDataStudio.png)
--
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- # Docker
--
-- ![alt text](./Images_Notebook-03/docker_facebook_share.png)
--
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- # Python
-- ![alt text](./Images_Notebook-03/python-logo.png)
--
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- ## You can install Python from within Azure Data Studio.
--
-- ### 1) Change the Kernel from a notebook to 'Python 3'
--
-- ![alt text](./Images_Notebook-03/python-change-kernel.png)
--
-- ### 2) Follow the instructions to install 'Python' on your machine
--
-- ![alt text](./Images_Notebook-03/python-install.png)
--
-- ### 3) Add additional packages
--
-- ![alt text](./Images_Notebook-03/package_installer.png)
--
-- ### 4) Select the pandas package
-- ![alt text](./Images_Notebook-03/install_pandas.png)

-- %% [markdown]
-- # Lets try it !
--
-- ## First step click on connections
--
-- </br>
-- </br>
--
--
-- ![alt text](./Images_Notebook-03/Connection_Figure1.jpg)
--
-- </br>
-- </br>
--
-- ## Second step click on connections
--
-- ![alt text](./Images_Notebook-03/Connection_Figure2.jpg)
-- </br>
-- </br>
--
-- ## Third step select the type of deployment
--
-- ![alt text](./Images_Notebook-03/Connection_Figure3.jpg)
--
-- </br>
-- </br>
--
-- ![alt text](https://media.giphy.com/media/l4Ep5UvSRBFPBeH0k/giphy.gif)
--
-- </br>
-- </br>
-- </br>
-- </br>
-- </br>
--
-- ## Hey beardy this is the secret password
--
-- @123456789P
